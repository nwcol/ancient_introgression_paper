# %%
import dpluspy
import demes 
import moments
import msprime
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define paths to models
model0_file = "notebook_models/graph0.yaml"
params0_file = "notebook_models/params0.yaml"
model1_file = "notebook_models/graph1.yaml"
params1_file = "notebook_models/params1.yaml"

true_model_file = model1_file

# %%
# Parameters
r = 1e-8
u = 1.3e-8
u_std = 2e-9
L = int(5e6)
n_reps = 100
pop_ids = ["popX"]
samples = {pop_id: 1 for pop_id in pop_ids}
bins = np.logspace(-6, -2, 17)

# %%
# Define simulation and D+ parsing functions

def simulate():
    graph = demes.load(true_model_file)
    demog = msprime.Demography.from_demes(graph)
    tss = msprime.sim_ancestry(
        demography=demog,
        samples=samples,
        sequence_length=L,
        recombination_rate=r,
        num_replicates=n_reps,
    )
    mtss = [msprime.sim_mutations(ts, np.random.normal(u, u_std)) for ts in tss]
    return mtss


def parse_stats(mtss):
    # Parse statistics from simulation results
    intervals = [[1, L + 1, L + 1]]
    pop_mapping = {x: [x] for x in samples} 
    stats = dict()
    for ii, ts in enumerate(mtss):
        if ii == 0:
            stats_ii = dpluspy.parsing.parse_stats(
                ts, 
                get_denoms=True,
                pop_mapping=pop_mapping, 
                r=r, 
                r_bins=bins, 
                intervals=intervals,
                chrom=ii, 
                ts_sample_ids=pop_ids, 
                overhang=None,
                verbose=False
            )
        else:
            stats_ii = dpluspy.parsing.parse_stats(
                ts, 
                get_denoms=False,
                pop_mapping=pop_mapping, 
                r=r, 
                r_bins=bins, 
                intervals=intervals,
                chrom=ii, 
                ts_sample_ids=pop_ids, 
                overhang=None,
                verbose=False
            )
            for jj in range(len(intervals)):
                stats_ii[(ii, jj)]["denoms"] = stats[(0, jj)]["denoms"]
        stats.update(stats_ii)
    return stats

# %%
# Run simulations
mtss = simulate()
# Parse statistics and do the bootstrap
stats = parse_stats(mtss)
bootreps = dpluspy.bootstrapping.get_bootstrap_reps(
    stats, num_reps=100, weighted=False)
varcovs = dpluspy.bootstrapping.compute_varcovs(bootreps)
means = dpluspy.bootstrapping.means_across_regions(stats)

# %%
def fit_model(ms, vcs, graph_file, param_file, out_file):
    """
    Fit a model, forcing convergence to within 1% LL.
    """
    ll_log = []
    thresh = 0.01
    counter = 0
    max_tries = 10
    converged = False
    while not converged:
        ret = dpluspy.inference.optimize(
            graph_file,
            param_file,
            ms,
            vcs,
            pop_ids=pop_ids,
            bins=bins,
            u=u,
            perturb=0.05,
            method="powell",
            log=True,
            max_iter=100,
            verbose=200,
            output=out_file,
            overwrite=True
        )
        ll = ret[-1]
        if counter > 0:
            diffs = np.abs((np.array(ll_log) - ll) / ll)
            if np.any(diffs < thresh):
                converged = True
            if counter > max_tries:
                raise ValueError("Failed to obtain convergence")
        ll_log.append(ll)
        counter += 1
    return ret

# %%
# Fit the null and underlying (complex) models; force ll1 > ll0
out0 = "notebook_models/model1_fit0.yaml"
out1 = "notebook_models/model1_fit1.yaml"
pnames0, params0, ll0 = fit_model(
    means, varcovs, model0_file, params0_file, out0)
ll1 = -1e10
max_tries = 10
tries = 0
while ll1 <= ll0:
    pnames1, params1, ll1 = fit_model(
        means, varcovs, model1_file, params1_file, out1)
    tries += 1
    if tries > max_tries:
        raise ValueError("Cannot achieve ll1 > ll0")
# Out:
# [21-07-25 13:53:18] Fitting D+ to data for ['popX']
# Call         LL [       N_X]
# init          - [  1.44e+04]
# Finished with flag 0
# Log-likelihood:	-12.43
# Fitted parameters:
# N_X	1.36e+04
# [21-07-25 13:53:19] Fitting D+ to data for ['popX']
# Call         LL [       N_X]
# init          - [  1.57e+04]
# Finished with flag 0
# Log-likelihood:	-12.43
# Fitted parameters:
# N_X	1.36e+04
# [21-07-25 13:53:19] Fitting D+ to data for ['popX']
# Call         LL [      N_X0       T_0      N_X1]
# init          - [  1.55e+04  1.93e+03  5.22e+03]
# 200       -0.07 [  1.49e+04  1.97e+03  4.89e+03]
# Finished with flag 0
# Log-likelihood:	-0.04
# Fitted parameters:
# N_X0	1.49e+04
# T_0	2.38e+03
# N_X1	5.56e+03
# [21-07-25 13:53:36] Fitting D+ to data for ['popX']
# Call         LL [      N_X0       T_0      N_X1]
# init          - [  1.57e+04  2.03e+03  4.83e+03]
# 200       -2.24 [  1.49e+04  1.83e+03  4.96e+03]
# Finished with flag 0
# Log-likelihood:	-0.04
# Fitted parameters:
# N_X0	1.49e+04
# T_0	2.38e+03
# N_X1	5.56e+03

# %%
# Plot model fits
model0 = dpluspy.inference.compute_bin_stats(out0, bins=bins, u=u, 
    sampled_demes=pop_ids)
model1 = dpluspy.inference.compute_bin_stats(out1, bins=bins, u=u, 
    sampled_demes=pop_ids)
dpluspy.plotting.plot_D_plus_curves(models=[model0, model1], bins=bins, 
    pop_ids=pop_ids, means=means, varcovs=varcovs, ax_size=2.5,
    labels=["simulation", "model0", "model1"])

# %%
# Plot errors against simulated data
res0 = [(m - s) / s for m, s in zip(model0, means)]
res1 = [(m - s) / s for m, s in zip(model1, means)]
zeros = [np.array([0])] * len(means)
vs = [v / s ** 2 for v, s in zip(varcovs, means)]
dpluspy.plotting.plot_D_plus_curves(models=[res0, res1], bins=bins, 
    varcovs=vs, means=zeros, pop_ids=pop_ids, ax_size=2.5,
    labels=["simulation", "model0", "model1"],
    title="Residuals")

# %%
# Summarize fitted parameters
print(f"Model 0 (null) ll = {ll0:.3}")
print("Param\tvalue")
for name, val in zip(pnames0, params0):
    print(f"{name}\t{val:.3}")

print(f"\nModel 1 (full, underlying) ll = {ll1:.3}")
print("Param\tvalue")
for name, val in zip(pnames1, params1):
    print(f"{name}\t{val:.3}")

weights = (0, 0.5, 0.5)
D_naive = 2 * (ll1 - ll0)
p_naive = moments.Godambe.sum_chi2_ppf(D_naive, weights=weights)

print("\nNaive (unadjusted) LR statistic:")
print(f"D =\t{D_naive:.3}")
print(f"p =\t{p_naive:.3}")
# Out:
# Model 0 (null) ll = -12.4
# Param	value
# N_X	1.36e+04
#
# Model 1 (full, underlying) ll = -0.0393
# Param	value
# N_X0	1.49e+04
# T_0	2.38e+03
# N_X1	5.56e+03
#
# Naive (unadjusted) LR statistic:
# D =	24.8
# p =	2.4e-06

# %%
# Compute the LRT adjustment at model 1 MLE parameters

# Set up complex model arguments
_, __, model_args = dpluspy.uncerts.set_up_model_args(
    model1_file, params1_file, bins=bins, pop_ids=pop_ids, u=u)

p_lrt = params1
steps = p_lrt[1:] * 0.01
nested_idx = np.array([1, 2])

# Print a summary of the parameter setup
print("Param\tvalue\tnested?\tstep")
nest_idx = 0
for ii, (name, val) in enumerate(zip(pnames1, p_lrt)):
    nested = True if ii in nested_idx else False
    if nested:
        step = f"{steps[nest_idx]:.3}"
        nest_idx += 1
    else:
        step = "---"
    print(f"{name}\t{val:.3}\t{nested}\t{step}")

adj = dpluspy.uncerts.LRT_adjust(
    p_lrt, 
    model_args, 
    means, 
    varcovs, 
    bootreps, 
    nested_idx, 
    steps=steps,
    verbose=0
)

# Compute the adjusted LR test statistic
D_adj = adj * D_naive
p_adj = moments.Godambe.sum_chi2_ppf(D_adj, weights=weights)

print(f"\nadj =\t{adj:.3}")
print(f"D_adj =\t{D_adj:.3}")
print(f"p =\t{p_adj:.3}")
# Out:
# Param	value	nested?	step
# N_X0	1.49e+04	False	---
# T_0	2.38e+03	True	23.8
# N_X1	5.56e+03	True	55.6
#
# adj =	0.133
# D_adj =	3.3
# p =	0.131

# %%
# Compute the LRT adjustment at model 0 MLE parameters

p_lrt = np.concatenate([params0, [1, params0[0]]])
steps = np.array([3000, 15000]) * 0.01

# Print a summary of the parameter setup
print("Param\tvalue\tnested?\tstep")
nest_idx = 0
for ii, (name, val) in enumerate(zip(pnames1, p_lrt)):
    nested = True if ii in nested_idx else False
    if nested:
        step = f"{steps[nest_idx]:.3}"
        nest_idx += 1
    else:
        step = "---"
    print(f"{name}\t{val:.3}\t{nested}\t{step}")

adj = dpluspy.uncerts.LRT_adjust(
    p_lrt, 
    model_args, 
    means, 
    varcovs, 
    bootreps, 
    nested_idx, 
    steps=steps,
    verbose=0
)

# Compute the adjusted LR test statistic
D_adj = adj * D_naive
p_adj = moments.Godambe.sum_chi2_ppf(D_adj, weights=weights)

print(f"\nadj =\t{adj:.3}")
print(f"D_adj =\t{D_adj:.3}")
print(f"p =\t{p_adj:.3}")
# Out:
# Param	value	nested?	step
# N_X0	1.36e+04	False	---
# T_0	1.0	True	30.0
# N_X1	1.36e+04	True	1.5e+02
#
# adj =	3.35e+11
# D_adj =	8.29e+12
# p =	0.0

# %%
p_lrt = np.concatenate([params0, [params1[1], params0[0]]])
steps = p_lrt[2:] * 0.01
nested_idx = np.array([2])

adj = dpluspy.uncerts.LRT_adjust(
    p_lrt, 
    model_args, 
    means, 
    varcovs, 
    bootreps, 
    nested_idx, 
    steps=steps,
    verbose=0
)
print(adj)
# Out:
# 0.0007639612213607099

# %%
# Evaluate naive D across some bootstrap replicates 
rep_lls = []
for ii in range(5):
    pnames0, params0, ll0 = fit_model(
        bootreps[ii], varcovs, model0_file, params0_file, None)
    pnames1, params1, ll1 = fit_model(
        bootreps[ii], varcovs, out1, params1_file, None)
    if ll1 < ll0:
        continue 
    rep_lls.append([ll0, ll1])
# Out:
# [21-07-25 13:53:52] Fitting D+ to data for ['popX']
# Call         LL [       N_X]
# init          - [   1.5e+04]
# Finished with flag 0
# Log-likelihood:	-14.16
# Fitted parameters:
# N_X	1.37e+04
# [21-07-25 13:53:52] Fitting D+ to data for ['popX']
# Call         LL [       N_X]
# init          - [  1.53e+04]
# Finished with flag 0
# Log-likelihood:	-14.16
# Fitted parameters:
# N_X	1.37e+04
# [21-07-25 13:53:52] Fitting D+ to data for ['popX']
# Call         LL [      N_X0       T_0      N_X1]
# init          - [  1.44e+04  2.41e+03  5.49e+03]
# 200     -208.13 [  1.51e+04  4.11e+02  4.94e+03]
# Finished with flag 0
# Log-likelihood:	-0.05
# Fitted parameters:
# N_X0	1.51e+04
# T_0	2.03e+03
# N_X1	4.87e+03
# [21-07-25 13:54:05] Fitting D+ to data for ['popX']
# Call         LL [      N_X0       T_0      N_X1]
# init          - [  1.49e+04  2.44e+03  5.55e+03]
# 200     -208.07 [  1.51e+04  4.14e+02  4.97e+03]
# Finished with flag 0
# Log-likelihood:	-0.05
# Fitted parameters:
# N_X0	1.51e+04
# T_0	2.03e+03
# N_X1	4.87e+03
# [21-07-25 13:54:16] Fitting D+ to data for ['popX']
# Call         LL [       N_X]
# init          - [  1.49e+04]
# Finished with flag 0
# Log-likelihood:	-15.03
# Fitted parameters:
# N_X	1.39e+04
# [21-07-25 13:54:16] Fitting D+ to data for ['popX']
# Call         LL [       N_X]
# init          - [  1.53e+04]
# Finished with flag 0
# Log-likelihood:	-15.03
# Fitted parameters:
# N_X	1.39e+04
# [21-07-25 13:54:17] Fitting D+ to data for ['popX']
# Call         LL [      N_X0       T_0      N_X1]
# init          - [  1.53e+04  2.28e+03   5.7e+03]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 6
#       3 for ii in range(5):
#       4     pnames0, params0, ll0 = fit_model(
#       5         bootreps[ii], varcovs, model0_file, params0_file, None)
# ----> 6     pnames1, params1, ll1 = fit_model(
#       7         bootreps[ii], varcovs, out1, params1_file, None)
#       8     if ll1 < ll0:
#       9         continue
#
# Cell In[6], line 11, in fit_model(ms, vcs, graph_file, param_file, out_file)
#       9 converged = False
#      10 while not converged:
# ---> 11     ret = dpluspy.inference.optimize(
#      12         graph_file,
#      13         param_file,
#      14         ms,
#      15         vcs,
#      16         pop_ids=pop_ids,
#      17         bins=bins,
#      18         u=u,
#      19         perturb=0.05,
#      20         method="powell",
#      21         log=True,
#      22         max_iter=100,
#      23         verbose=200,
#      24         output=out_file,
#      25         overwrite=True
#      26     )
#      27     ll = ret[-1]
#      28     if counter > 0:
#
# File ~/Devel/dpluspy/dpluspy/inference.py:511, in optimize(graph_file, param_file, means, varcovs, pop_ids, bins, u, method, max_iter, max_calls, log, verbose, overwrite, output, use_H, use_afs, afs, L, perturb, fit_mutation_rate, u_bounds, fit_ancestral_misid, misid_guess, approx_method)
#     508     fit_params, fopt, num_iter, func_calls, flag = ret[:5]
#     510 elif method == "powell":
# --> 511     ret = scipy.optimize.fmin_powell(
#     512         objective,
#     513         params_0,
#     514         args=args,
#     515         maxiter=max_iter,
#     516         maxfun=max_calls,
#     517         full_output=True,
#     518         disp=False
#     519     )
#     520     fit_params, fopt, direc, num_iter, func_calls, flag = ret[:6]
#     522 elif method == "bfgs":
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/scipy/optimize/_optimize.py:3360, in fmin_powell(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, direc)
#    3351 opts = {'xtol': xtol,
#    3352         'ftol': ftol,
#    3353         'maxiter': maxiter,
#    (...)   3356         'direc': direc,
#    3357         'return_all': retall}
#    3359 callback = _wrap_callback(callback)
# -> 3360 res = _minimize_powell(func, x0, args, callback=callback, **opts)
#    3362 if full_output:
#    3363     retlist = (res['x'], res['fun'], res['direc'], res['nit'],
#    3364                res['nfev'], res['status'])
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/scipy/optimize/_optimize.py:3529, in _minimize_powell(func, x0, args, callback, bounds, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    3527 direc1 = direc[i]
#    3528 fx2 = fval
# -> 3529 fval, x, direc1 = _linesearch_powell(func, x, direc1,
#    3530                                      tol=xtol * 100,
#    3531                                      lower_bound=lower_bound,
#    3532                                      upper_bound=upper_bound,
#    3533                                      fval=fval)
#    3534 if (fx2 - fval) > delta:
#    3535     delta = fx2 - fval
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/scipy/optimize/_optimize.py:3205, in _linesearch_powell(func, p, xi, tol, lower_bound, upper_bound, fval)
#    3202     return ((fval, p, xi) if fval is not None else (func(p), p, xi))
#    3203 elif lower_bound is None and upper_bound is None:
#    3204     # non-bounded minimization
# -> 3205     res = _recover_from_bracket_error(_minimize_scalar_brent,
#    3206                                       myfunc, None, tuple(), xtol=tol)
#    3207     alpha_min, fret = res.x, res.fun
#    3208     xi = alpha_min * xi
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/scipy/optimize/_optimize.py:3098, in _recover_from_bracket_error(solver, fun, bracket, args, **options)
#    3079 def _recover_from_bracket_error(solver, fun, bracket, args, **options):
#    3080     # `bracket` was originally written without checking whether the resulting
#    3081     # bracket is valid. `brent` and `golden` built on top of it without
#    (...)   3095     # storing the information needed by `minimize_scalar` in the error object,
#    3096     # and intercepting it here.
#    3097     try:
# -> 3098         res = solver(fun, bracket, args, **options)
#    3099     except BracketError as e:
#    3100         msg = str(e)
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/scipy/optimize/_optimize.py:2697, in _minimize_scalar_brent(func, brack, args, xtol, maxiter, disp, **unknown_options)
#    2694 brent = Brent(func=func, args=args, tol=tol,
#    2695               full_output=True, maxiter=maxiter, disp=disp)
#    2696 brent.set_bracket(brack)
# -> 2697 brent.optimize()
#    2698 x, fval, nit, nfev = brent.get_result(full_output=True)
#    2700 success = nit < maxiter and not (np.isnan(x) or np.isnan(fval))
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/scipy/optimize/_optimize.py:2534, in Brent.optimize(self)
#    2532 else:
#    2533     u = x + rat
# -> 2534 fu = func(*((u,) + self.args))      # calculate new output value
#    2535 funcalls += 1
#    2537 if (fu > fx):                 # if it's bigger than current
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/scipy/optimize/_optimize.py:3198, in _linesearch_powell.<locals>.myfunc(alpha)
#    3197 def myfunc(alpha):
# -> 3198     return func(p + alpha*xi)
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/scipy/optimize/_optimize.py:542, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     540 ncalls[0] += 1
#     541 # A copy of x is sent to the user function (gh13740)
# --> 542 fx = function(np.copy(x), *(wrapper_args + args))
#     543 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     544 # backwards-compatibility, also allow np.array([1.3]),
#     545 # np.array([[1.3]]) etc.
#     546 if not np.isscalar(fx):
#
# File ~/Devel/dpluspy/dpluspy/inference.py:318, in _log_object_func(log_p, *args, **kwargs)
#     314 """
#     315 Objective function for optimizing over the log of parameters.
#     316 """
#     317 p = np.exp(log_p - 1)
# --> 318 return _object_func(p, *args, **kwargs)
#
# File ~/Devel/dpluspy/dpluspy/inference.py:282, in _object_func(params, builder, options, means, varcovs, sampled_demes, sample_times, u, bins, lower_bounds, upper_bounds, constraints, verbose, use_H, use_afs, afs, L, fit_mutation_rate, fit_ancestral_misid, approx_method)
#     280 builder = moments.Demes.Inference._update_builder(builder, options, params)
#     281 graph = demes.Graph.fromdict(builder)
# --> 282 model = compute_bin_stats(
#     283     graph,
#     284     sampled_demes,
#     285     sample_times=sample_times,
#     286     u=u,
#     287     bins=bins,
#     288     phased=False,
#     289     approx=approx_method
#     290 )
#     291 ll = composite_ll(model, means, varcovs, use_H=use_H)
#     293 if use_afs:
#
# File ~/Devel/dpluspy/dpluspy/inference.py:178, in compute_bin_stats(graph, sampled_demes, sample_times, u, bins, approx, phased, steps)
#     168     model = DPlusStats.from_moments(
#     169         graph,
#     170         sampled_demes,
#    (...)    174         phased=phased
#     175     )
#     177 elif approx == "simpsons":
# --> 178     y_edges = DPlusStats.from_moments(
#     179         graph,
#     180         sampled_demes,
#     181         sample_times=sample_times,
#     182         rs=bins,
#     183         u=u,
#     184         phased=phased
#     185     )
#     186     midpoints = (bins[:-1] + bins[1:]) / 2
#     187     y_mids = DPlusStats.from_moments(
#     188         graph,
#     189         sampled_demes,
#    (...)    193         phased=phased
#     194     )
#
# File ~/Devel/dpluspy/dpluspy/datastructures.py:89, in DPlusStats.from_moments(cls, graph, sampled_demes, sample_times, rs, u, phased)
#      87 if isinstance(graph, str):
#      88     graph = demes.load(graph)
# ---> 89 y = moments.Demes.LD(
#      90     graph,
#      91     sampled_demes,
#      92     sample_times=sample_times,
#      93     theta=None,
#      94     r=rs,
#      95     u=u
#      96 )
#      97 num_demes = len(sampled_demes)
#      98 num_stats = (num_demes ** 2 + num_demes) // 2
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/moments/Demes/Demes.py:458, in LD(g, sampled_demes, sample_times, rho, theta, r, u)
#     455     raise ValueError("Mutation rate must be positive")
#     457 # compute LD
# --> 458 y = _compute_LD(
#     459     demo_events,
#     460     demes_present,
#     461     nu_funcs,
#     462     mig_mats,
#     463     Ts,
#     464     frozen_pops,
#     465     selfing_rates,
#     466     root_selfing_rate,
#     467     rho,
#     468     theta,
#     469 )
#     471 y = _reorder_LD(y, sampled_pops)
#     473 # simplify pop id name if ancient sample at end time of that deme
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/moments/Demes/Demes.py:1284, in _compute_LD(demo_events, demes_present, nu_funcs, migration_matrices, integration_times, frozen_demes, selfing_rates, root_selfing_rate, rho, theta)
#    1280 integration_intervals = sorted(list(demes_present.keys()))[::-1]
#    1282 # set up initial steady-state LD for ancestral deme
#    1283 y = moments.LD.LDstats(
# -> 1284     moments.LD.Numerics.steady_state(
#    1285         [1], theta=theta, rho=rho, selfing_rate=[root_selfing_rate]
#    1286     ),
#    1287     num_pops=1,
#    1288     pop_ids=demes_present[integration_intervals[0]],
#    1289 )
#    1291 # for each set of demographic events and integration epochs, step through
#    1292 # integration, apply events, and then reorder populations to align with demes
#    1293 # present in the next integration epoch
#    1294 for (T, nu, M, frozen, interval, selfing_rate) in zip(
#    1295     integration_times,
#    1296     nu_funcs,
#    (...)   1300     selfing_rates,
#    1301 ):
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/moments/LD/Numerics.py:455, in steady_state(nus, m, rho, theta, selfing_rate)
#     453 y_ss = []
#     454 for r in rho:
# --> 455     y_ss.append(two_pop_ld_ss(nus, m, theta, r, selfing_rate, h_ss))
#     456 return y_ss + [h_ss]
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/moments/LD/Numerics.py:447, in steady_state.<locals>.two_pop_ld_ss(nus, m, theta, rho, selfing_rate, h_ss)
#     445 D = Matrices.drift_ld(n, nus)
#     446 M = Matrices.migration_ld(n, m)
# --> 447 return factorized(D + R + M)(-U.dot(h_ss))
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/scipy/sparse/_base.py:559, in _spbase.__add__(self, other)
#     557     if other.shape != self.shape:
#     558         raise ValueError("inconsistent shapes")
# --> 559     return self._add_sparse(other)
#     560 elif isdense(other):
#     561     other = np.broadcast_to(other, self.shape)
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/scipy/sparse/_compressed.py:386, in _cs_matrix._add_sparse(self, other)
#     385 def _add_sparse(self, other):
# --> 386     return self._binopt(other, '_plus_')
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/scipy/sparse/_compressed.py:1360, in _cs_matrix._binopt(self, other, op)
#    1357 fn = getattr(_sparsetools, self.format + op + self.format)
#    1359 maxnnz = self.nnz + other.nnz
# -> 1360 idx_dtype = self._get_index_dtype((self.indptr, self.indices,
#    1361                              other.indptr, other.indices),
#    1362                             maxval=maxnnz)
#    1363 indptr = np.empty(self.indptr.shape, dtype=idx_dtype)
#    1364 indices = np.empty(maxnnz, dtype=idx_dtype)
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/scipy/sparse/_base.py:1376, in _spbase._get_index_dtype(self, arrays, maxval, check_contents)
#    1373 from ._sputils import get_index_dtype
#    1375 # Don't check contents for array API
# -> 1376 return get_index_dtype(arrays,
#    1377                        maxval,
#    1378                        (check_contents and not isinstance(self, sparray)))
#
# File ~/venvs/dpluspy/lib/python3.11/site-packages/scipy/sparse/_sputils.py:321, in get_index_dtype(arrays, maxval, check_contents)
#     319 for arr in arrays:
#     320     arr = np.asarray(arr)
# --> 321     if not np.can_cast(arr.dtype, np.int32):
#     322         if check_contents:
#     323             if arr.size == 0:
#     324                 # a bigger type not needed
#
# KeyboardInterrupt:

# %%
rep_lls = np.array(rep_lls)
rep_Ds = 2 * (rep_lls[:, 1] - rep_lls[:, 0])
print(rep_Ds)
# Out:
# [21.28449974 37.68602847 26.98848141 35.5448332  34.53689008]
