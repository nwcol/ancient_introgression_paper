# %%
import numpy as np
import pandas 
import dpluspy 
import demes
import moments

# %%
null_model_file = "models/hn_null_model.yaml"
null_param_file = "models/hn_null_model_params.yaml"

builder = moments.Demes.Inference._get_demes_dict(null_model_file)
options = moments.Demes.Inference._get_params_dict(null_param_file)
pnames = [x["name"] for x in options['parameters']]

for model in [0, 1, 5]:
    for rep in range(10):
        fname = f"results/hn_model_{model}_rep_{rep}.csv"
        tbl = pandas.read_csv(fname)
        ll0, ll1 = list(tbl["ll"])
        print(ll1 - ll0)
        params = [list(tbl[pname])[0] for pname in pnames]
        builder = moments.Demes.Inference._update_builder(builder, options, params)
        graph = demes.Graph.fromdict(builder)
        out_fname = f"null_models/hn_null_model_{model}_rep_{rep}.yaml"
        demes.dump(graph, out_fname)
# Out:
# 23.691486063670727
# 0.03112445301191613
# -0.01255988247335793
# -0.07611694200143759
# 0.08613054772750317
# 0.011901442364383286
# 0.4257221831488849
# 28.510408580675218
# 0.06149325123300997
# 1.6112681345278546
# 10.077360645307921
# 27.472354191309716
# 24.530482763914257
# 4.013830727595446
# 7.235334126724485
# 8.651531132502338
# 11.858592804974746
# 6.551250028718449
# 8.77557939171319
# 12.197275784135833
# 67.04585003944771
# 139.57323467866968
# 51.682065406192066
# 66.39241503517765
# 101.32673238621084
# 68.05865650276249
# 151.9414000441141
# 28.599556560699252
# 194.8559897654275
# 80.16629739975329
