# %%
import numpy as np

# %%
n = 2 * 71702
Ne = 2e4
Ttot = 2 * sum([1 / i for i in range(1, n - 1)])
print(Ttot)
print(Ttot * 2 * Ne)
print(1 / 1.015e-7)
# Out:
# 24.901252611301807
# 996050.1044520723
# 9852216.748768473

# %%
Ttot = 1 / 1.015e-7

# MR field from Roulette VCF file
mr = 0.1
P0 = np.exp(-mr)
print(P0)
u = -np.log(P0)/Ttot
print(u)
# Out:
# 0.9048374180359595
# 1.0150000000000007e-08
